# %% [markdown]
# # 20. 有效的括号
#
# 给定一个只包括 '('，')'，'{'，'}'，'['，']' 的字符串 s ，判断字符串是否有效。
#
# 有效字符串需满足：
#
# - 左括号必须用相同类型的右括号闭合。
# - 左括号必须以正确的顺序闭合。
# - 每个右括号都有一个对应的相同类型的左括号。

# %%
class Solution:
    def isValid(self, s: str) -> bool:
        from collections import deque
        # 左括号入栈，右括号看看栈顶元素是否匹配，如果匹配就pop，反之字符串无效
        bracket_map = {
            ')': '(',
            '}': '{',
            ']': '['
        }
        q = deque()
        for char in s:
            if char in bracket_map:
                if not q:
                    return False
                if q[-1] != bracket_map[char]:
                    return False
                q.pop()
            else:
                q.append(char)
        return not q
