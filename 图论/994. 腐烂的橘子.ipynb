# %% [markdown]
# # 994. 腐烂的橘子
#
# 在给定的 m x n 网格 grid 中，每个单元格可以有以下三个值之一：
#
# - 值 0 代表空单元格；
# - 值 1 代表新鲜橘子；
# - 值 2 代表腐烂的橘子。
#
# 每分钟，腐烂的橘子 周围 4 个方向上相邻 的新鲜橘子都会腐烂。
#
# 返回 直到单元格中没有新鲜橘子为止所必须经过的最小分钟数。如果不可能，返回 -1 。
#
#
#
# 示例1：
#
# ![1](https://assets.leetcode.cn/aliyun-lc-upload/uploads/2019/02/16/oranges.png)
#
# ```text
# 输入：grid = [[2,1,1],[1,1,0],[0,1,1]]
# 输出：4
# ```
#
# 示例2：
#
# ```text
# 输入：grid = [[2,1,1],[0,1,1],[1,0,1]]
# 输出：-1
# 解释：左下角的橘子（第 2 行， 第 0 列）永远不会腐烂，因为腐烂只会发生在 4 个方向上。
# ```
#
# 示例3：
#
# ```text
# 输入：grid = [[0,2]]
# 输出：0
# 解释：因为 0 分钟时已经没有新鲜橘子了，所以答案就是 0 。
# ```

# %% [markdown]
# ## 广度优先搜索
#
# 这是一道模拟题，按照题目处理即可。一次遍历一层节点，一共遍历多少层时间就是多少。
#
# 需要注意的是边界条件，如果循环结束还有新鲜水果那就说明不可能，返回 -1。

# %%
class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:
        from collections import deque

        def isInArea(i, j):
            return (0 <= i < m) and (0 <= j < n)

        # 广度优先搜索，看扫了几层
        m = len(grid)
        n = len(grid[0])

        move_list = [(-1, 0), (1, 0), (0, -1), (0, 1)]

        fresh_count = 0
        time = 0
        q = deque()
        for i in range(m):
            for j in range(n):
                if grid[i][j] == 1:
                    fresh_count += 1
                elif grid[i][j] == 2:
                    q.append((i, j))

        while q and fresh_count:
            length = len(q)
            time += 1
            print(q)
            for _ in range(length):
                i, j = q.popleft()
                # 腐烂扩散
                for k in move_list:
                    x = i + k[0]
                    y = j + k[1]
                    if isInArea(x, y) and grid[x][y] == 1:
                        grid[x][y]=2
                        fresh_count -= 1
                        q.append((x, y))


        if fresh_count:
            return -1

        return time
